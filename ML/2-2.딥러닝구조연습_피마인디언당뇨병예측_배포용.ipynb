# %% [markdown]
# # 딥러닝 구조 연습2

# %% [markdown]
# ## 라이브러리 로드

# %%
import pandas as pd
import tensorflow as tf

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## 데이터 로드

# %%
df = pd.read_csv('./dataset/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## 데이터 준비

# %%
X_train = df.iloc[:,0:-1]

y_train = df['Outcome']

type(X_train),type(y_train)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
X_train.ndim
# Out:
# 2

# %%
X_train.shape
# Out:
# (768, 8)

# %% [markdown]
# ## 딥러닝 구성하기
#
# http://alexlenail.me/NN-SVG/index.html

# %%
# 모델을 설정합니다.
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 12)                108
#
#  dense_2 (Dense)             (None, 1)                 13
#
# ...
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 딥러닝 설정하기

# %%
# 모델을 컴파일합니다.
# 이진분류 loss: binary_crossentropy
# 
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['Accuracy'])

# %%
X_train.shape
# Out:
# (768, 8)

# %% [markdown]
# ## 딥러닝 훈련하기

# %%
epo_hist = model.fit(X_train,y_train,epochs=200)
# Out:
# Epoch 1/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4701 - Accuracy: 0.7865
# Epoch 2/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4539 - Accuracy: 0.7904
# Epoch 3/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4560 - Accuracy: 0.7917
# Epoch 4/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4643 - Accuracy: 0.7734
# Epoch 5/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4754 - Accuracy: 0.7799
# Epoch 6/200
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4554 - Accuracy: 0.7839
# Epoch 7/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4576 - Accuracy: 0.7878
# Epoch 8/200
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4505 - Accuracy: 0.7930
# Epoch 9/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4470 - Accuracy: 0.7904
# Epoch 10/200
# ...

# %%
# 모델을 실행합니다.

# %% [markdown]
# ## 평가하기

# %%
# 결과를 출력합니다.
model.evaluate(X_train,y_train)
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4710 - Accuracy: 0.7734
# [0.4710230827331543, 0.7734375]

# %%
import matplotlib.pyplot as plt
plt.plot(epo_hist.history['loss'])

# %% [markdown]
# ## 전체 코드

# %%
import pandas as pd
import tensorflow as tf

# 딥러닝을 구동하는 데 필요한 케라스 함수를 불러옵니다.
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

df=pd.read_csv('./dataset/diabetes.csv')
# df.head()

X_train=df.drop(['Outcome'],axis=1)
y_train=df['Outcome']

# type(X_train),type(y_train)

# X_train.ndim
# X_train.shape

# 모델을 설정합니다.
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'),)
model.add(Dense(1, activation = 'sigmoid'))

# model.summary()

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['Accuracy'])

epo_hist = model.fit(X_train,y_train,epochs=200)

# model.evaluate(X_train,y_train)

import matplotlib.pyplot as plt
plt.plot(epo_hist.history['loss'])
plt.show()
# Out:
# Epoch 1/200
# 384/384 [==============================] - 1s 1ms/step - loss: 2.8174 - Accuracy: 0.4922
# Epoch 2/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.9946 - Accuracy: 0.5703
# Epoch 3/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.7426 - Accuracy: 0.6589
# Epoch 4/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.6945 - Accuracy: 0.6823
# Epoch 5/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.6751 - Accuracy: 0.6810
# Epoch 6/200
# 384/384 [==============================] - 1s 1ms/step - loss: 0.7092 - Accuracy: 0.6641
# Epoch 7/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.6583 - Accuracy: 0.6966
# Epoch 8/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.6273 - Accuracy: 0.6953
# Epoch 9/200
# 384/384 [==============================] - 0s 1ms/step - loss: 0.6401 - Accuracy: 0.6706
# Epoch 10/200
# ...

# %% [markdown]
# ## 실험
#
# 아래의 파라미터를 조정해보며 네트워크의 구성과 성능을 살펴봅시다.
# * Dense층의 유닛개수를 조정해 봅시다.
# * Dense층을 더 넣어 봅시다.
# * epoch수와 batch_size를 조정해 봅시다.

# %%
# 모델을 설정합니다.
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))


# model.summary()

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['Accuracy'])

epo_hist = model.fit(X_train,y_train,epochs=150)

# model.evaluate(X_train,y_train)

import matplotlib.pyplot as plt
plt.plot(epo_hist.history['loss'])
plt.show()
# Out:
# Epoch 1/150
# 24/24 [==============================] - 0s 1ms/step - loss: 20.6029 - Accuracy: 0.3490
# Epoch 2/150
# 24/24 [==============================] - 0s 2ms/step - loss: 6.4611 - Accuracy: 0.4258
# Epoch 3/150
# 24/24 [==============================] - 0s 1ms/step - loss: 2.8504 - Accuracy: 0.6055
# Epoch 4/150
# 24/24 [==============================] - 0s 2ms/step - loss: 2.3858 - Accuracy: 0.5638
# Epoch 5/150
# 24/24 [==============================] - 0s 2ms/step - loss: 2.0926 - Accuracy: 0.5703
# Epoch 6/150
# 24/24 [==============================] - 0s 2ms/step - loss: 1.8733 - Accuracy: 0.5469
# Epoch 7/150
# 24/24 [==============================] - 0s 2ms/step - loss: 1.7132 - Accuracy: 0.5690
# Epoch 8/150
# 24/24 [==============================] - 0s 2ms/step - loss: 1.5805 - Accuracy: 0.5599
# Epoch 9/150
# 24/24 [==============================] - 0s 2ms/step - loss: 1.4551 - Accuracy: 0.5846
# Epoch 10/150
# ...
